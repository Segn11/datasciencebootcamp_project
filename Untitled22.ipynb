# %% [markdown]
# <a href="https://colab.research.google.com/github/Segn11/datasciencebootcamp_project/blob/srypto4_i/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings('ignore')


## Load the data
kamis_df = pd.read_csv('/content/kamis_maize_prices.csv')
agri_df = pd.read_csv('/content/agriBORA_maize_prices.csv')
week469 = pd.read_csv('/content/agriBORA_maize_prices_weeks_46_to_49.csv')


kamis_df.head()


agri_df.head()


# Selecting all entries with White Maize
kdf = kamis_df[kamis_df['Commodity_Classification'].str.contains("White_Maize", na=False)].copy()


kdf.head(5)


## Selecting all entries in the agriBORA set with White Maize (all the data)
agri_df = agri_df[agri_df['Commodity_Classification'].str.contains("White_Maize", na=False)].copy()
agri_df.shape


## The unique counties in the agriBORA dataset
agri_df.County.unique()


## The unique counties in the KAMIS dataset
kdf.County.unique()


## The counties of interest
target_counties = {"Kiambu","Kirinyaga","Mombasa","Nairobi","Uasin-Gishu"}


## Restricting myself to target counties
kdf = kdf[kdf['County'].isin(target_counties)]
agri_df = agri_df[agri_df['County'].isin(target_counties)]


## Select the price columns (Wholesale)
kdf['price'] = pd.to_numeric(kdf['Wholesale'], errors='coerce')
agri_df['price'] = pd.to_numeric(agri_df['WholeSale'], errors='coerce')


## Convert Date to datetime object
kdf['Date'] = pd.to_datetime(kdf['Date'])
agri_df['Date'] = pd.to_datetime(agri_df['Date'])


# Weekly alignment (use Monday as start of ISO week)
agri_df["week"] = agri_df["Date"].dt.to_period("W").apply(lambda p: p.start_time)
kdf["week"] = kdf["Date"].dt.to_period("W").apply(lambda p: p.start_time)


agri_df.head()


## Aggregate to Count-Week wholesale mean
kdf_week = (
    kdf.groupby(['County', 'week'], as_index=False)['price']
    .mean()
    .rename(columns={'price' : 'kamis_price'})
)

agri_df_week = (
    agri_df.groupby(['County', 'week'], as_index=False)['price']
    .mean()
    .rename(columns={'price': 'agri_price'})
)


kdf_week.head()


agri_df_week.head()


## How many weeks of data is covered in each table ?

coverage_agr = (agri_df_week.groupby("County")["week"]
           .agg(min_date="min", max_date="max", weeks="nunique")
           .reset_index())
coverage_agr["dataset"] = "agribora"

coverage_kam = (kdf_week.groupby("County")["week"]
           .agg(min_date="min", max_date="max", weeks="nunique")
           .reset_index())
coverage_kam["dataset"] = "kamis"


coverage = pd.concat([coverage_agr, coverage_kam], ignore_index=True)


coverage


#



# Is there an overlap between kamis & agribora data ?
overlap = (
    agri_df_week.merge(kdf_week, on=['County', 'week'], how='inner')
    .sort_values(['County', 'week'])
)


overlap


# Ensure 'week' is datetime or sortable
overlap['week'] = pd.to_datetime(overlap['week'])

# Set style


# List of counties
counties = overlap['County'].unique()





## Do some stats if the overlap is not empty

if not overlap.empty:
    overlap["diff"] = overlap["agri_price"] - overlap["kamis_price"]
    stats = overlap.groupby("County").agg(
        n=("agri_price","size"),
        corr=("agri_price", lambda x: np.corrcoef(x, overlap.loc[x.index,"kamis_price"])[0,1] if len(x)>2 else np.nan),
        mean_bias=("diff","mean"),
        mae=("diff", lambda x: np.abs(x).mean())
    ).reset_index().round(3)
else:
    stats = pd.DataFrame(columns=["county_norm","n","corr","mean_bias","mae"])


stats


agri_df_week.shape, kdf_week.shape


### Forecast idea

## Back kdf_week & agri_df_week
kdf_week.head()


agri_df_week.head()



## Another Idea


agr = pd.read_csv("/content/agriBORA_maize_prices.csv", parse_dates=["Date"])
kamis = pd.read_csv("/content/kamis_maize_prices.csv", parse_dates=["Date"])

agr = pd.concat([agr, week469], ignore_index=True)

agr = pd.read_csv("/content/agriBORA_maize_prices.csv", parse_dates=["Date"])

# Filter to white maize
agr = agr[agr["Commodity_Classification"].str.contains("White_Maize", na=False)].copy()
kamis = kamis[kamis["Commodity_Classification"].str.contains("White_Maize", na=False)].copy()

def norm_county(s):
    return s.strip() if isinstance(s, str) else s

agr["county_norm"] = agr["County"].apply(norm_county)
kamis["county_norm"] = kamis["County"].apply(norm_county)

target_counties = ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]
agr = agr[agr["county_norm"].isin(target_counties)].copy()
kamis = kamis[kamis["county_norm"].isin(target_counties)].copy()

# Weekly aggregation
agr["week_start"] = agr["Date"].dt.to_period("W").apply(lambda p: p.start_time)
kamis["week_start"] = kamis["Date"].dt.to_period("W").apply(lambda p: p.start_time)

agr["agr_price"] = pd.to_numeric(agr["WholeSale"], errors="coerce")
kamis["kamis_price"] = pd.to_numeric(kamis["Wholesale"], errors="coerce")

agr_week = agr.groupby(["county_norm", "week_start"], as_index=False)["agr_price"].mean()
kamis_week = kamis.groupby(["county_norm", "week_start"], as_index=False)["kamis_price"].mean()


kamis_week.head()


# Kenyan county centroid coordinates (approximate)
# Source: Public GIS datasets / government county shapefiles (preloaded here manually)
data = {
    "county_norm": [
        "Baringo", "Bomet", "Bungoma", "Busia", "Elgeyo-Marakwet", "Embu",
        "Garissa", "Homa Bay", "Isiolo", "Kajiado", "Kakamega", "Kericho",
        "Kiambu", "Kilifi", "Kirinyaga", "Kisii", "Kisumu", "Kitui",
        "Kwale", "Laikipia", "Lamu", "Machakos", "Makueni", "Mandera",
        "Marsabit", "Meru", "Migori", "Mombasa", "Murang'a", "Nairobi",
        "Nakuru", "Nandi", "Narok", "Nyamira", "Nyandarua", "Nyeri",
        "Samburu", "Siaya", "Taita-Taveta", "Tana River", "Tharaka-Nithi",
        "Trans Nzoia", "Turkana", "Uasin-Gishu", "Vihiga", "Wajir", "West Pokot"
    ],
    "latitude": [
        0.469, -0.801, 0.569, 0.434, 1.046, -0.531,
        -0.453, -0.495, 0.352, -2.098, 0.307, -0.377,
        -1.030, -3.510, -0.498, -0.681, -0.091, -1.366,
        -4.175, 0.421, -2.162, -1.517, -2.247, 3.937,
        3.544, 0.355, -1.064, -4.043, -0.783, -1.286,
        -0.303, 0.205, -1.145, -0.566, -0.258, -0.419,
        0.993, -0.133, -3.316, -1.845, -0.283, 1.010,
        3.118, 0.539, 0.023, 1.748, 1.532
    ],
    "longitude": [
        35.990, 35.342, 34.564, 34.124, 35.363, 37.456,
        39.654, 34.639, 38.570, 36.789, 34.751, 35.279,
        36.868, 39.800, 37.318, 34.778, 34.761, 38.015,
        39.458, 36.787, 40.902, 37.263, 37.892, 41.847,
        37.998, 37.655, 34.473, 39.668, 36.605, 36.816,
        36.188, 35.117, 35.860, 34.935, 36.574, 36.947,
        37.537, 34.266, 37.757, 39.507, 37.908, 35.021,
        35.587, 35.283, 34.729, 40.060, 35.162
    ]
}

centroids = pd.DataFrame(data)
centroids.head()


present_counties = kamis_week["county_norm"].unique().tolist()
centroids = centroids[centroids["county_norm"].isin(present_counties)].reset_index(drop=True)

# Haversine distance function
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# Compute full distance matrix
counties = centroids["county_norm"].tolist()
dist_matrix = pd.DataFrame(np.zeros((len(counties), len(counties))),
                           index=counties, columns=counties)

for i, c1 in centroids.iterrows():
    for j, c2 in centroids.iterrows():
        dist_matrix.loc[c1["county_norm"], c2["county_norm"]] = haversine(
            c1["latitude"], c1["longitude"],
            c2["latitude"], c2["longitude"]
        )

# Compute nearest 3 neighbours for each county
nearest = {}
for c in counties:
    sorted_nei = dist_matrix.loc[c].sort_values()
    nearest[c] = list(sorted_nei.index[1:4])  # Skip itself at index 0

nearest_df = pd.DataFrame({
    "county": counties,
    "nearest_1": [nearest[c][0] for c in counties],
    "nearest_2": [nearest[c][1] for c in counties],
    "nearest_3": [nearest[c][2] for c in counties],
})

dist_matrix.shape


dist_matrix


nearest_df.head()


## Let see which counties are closest to our target_counties
closest_to_target = nearest_df[nearest_df["county"].isin(target_counties)]
closest_to_target


# --------------------------------------------
#   BUILD CLEAN WEEKLY PANEL PER COUNTY
#    (gap-filling + smoothing)
# --------------------------------------------

all_panels = []

for c in target_counties:
    sub = kamis_week[kamis_week["county_norm"] == c].copy()
    if sub.empty:
        continue

    # Continuous weekly index from first to last observed for that county
    min_d = sub["week_start"].min()
    max_d = sub["week_start"].max()
    full_weeks = pd.date_range(min_d, max_d, freq="W-MON")

    df = pd.DataFrame({"week_start": full_weeks})
    df["county_norm"] = c

    df = df.merge(sub[["week_start", "kamis_price"]],
                  on="week_start", how="left")

    # Fill missing KAMIS prices within that county
    df["kamis_price"] = df["kamis_price"].ffill().bfill()

    # 3-week rolling mean smoothing
    df["kamis_smooth"] = df["kamis_price"].rolling(3, min_periods=1).mean()

    all_panels.append(df)

kamis_panel = pd.concat(all_panels, ignore_index=True)

# Merge with Agribora weekly prices
panel = kamis_panel.merge(
    agr_week,
    on=["county_norm", "week_start"],
    how="left"
)

# --------------------------------------------
#  CREATE LAGS & TRAINING SET (H+1 MODEL)
# --------------------------------------------

panel = panel.sort_values(["county_norm", "week_start"])

for lag in [1, 2, 3]:
    panel[f"lag{lag}"] = panel.groupby("county_norm")["kamis_smooth"].shift(lag)

# Drop rows with missing lags or missing Agribora price
panel_train = panel.dropna(subset=["lag1", "lag2", "lag3", "agr_price"]).reset_index(drop=True)

X = panel_train[["kamis_smooth", "lag1", "lag2", "lag3", "county_norm"]]
y = panel_train["agr_price"]

# --------------------------------------------
#  UNIFIED SINGLE ML MODEL (ElasticNet)
# --------------------------------------------

numeric_features     = ["kamis_smooth", "lag1", "lag2", "lag3"]
categorical_features = ["county_norm"]

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

enet = ElasticNet(alpha=0.05, l1_ratio=0.2, random_state=42)

model = Pipeline(steps=[
    ("prep", preprocess),
    ("model", enet)
])

model.fit(X, y)

# Optionally inspect training fit quality:
y_pred_train = model.predict(X)
print("Train MAE:", mean_absolute_error(y, y_pred_train))
print("Train RMSE:", np.sqrt(mean_squared_error(y, y_pred_train)))

# --------------------------------------------
#  FORECAST H+1 AND H+2 FOR EACH COUNTY
#    using recursive prediction
# --------------------------------------------

future_rows = []

for c in target_counties:
    hist = panel[panel["county_norm"] == c].sort_values("week_start").copy()
    if hist.empty:
        continue

    # Last three smoothed KAMIS prices (after filling + smoothing)
    last3 = hist["kamis_smooth"].tail(3).values

    # Ensure we have 3 values (fall back if series shorter)
    if len(last3) == 1:
        lag1 = lag2 = lag3 = last3[-1]
    elif len(last3) == 2:
        lag1 = last3[-1]
        lag2 = lag3 = last3[-2]
    else:
        lag1 = last3[-1]
        lag2 = last3[-2]
        lag3 = last3[-3]

    last_week = hist["week_start"].max()

    # --- Horizon 1 (next week) ---
    h1_date = last_week + timedelta(days=7)
    X_h1 = pd.DataFrame({
        "kamis_smooth": [lag1],  # use last known smooth KAMIS as base
        "lag1": [lag1],
        "lag2": [lag2],
        "lag3": [lag3],
        "county_norm": [c],
    })
    pred_h1 = model.predict(X_h1)[0]

    # --- Horizon 2 (two weeks ahead) ---
    h2_date = h1_date + timedelta(days=7)
    # For h+2, treat h+1 prediction as the new "current" level
    X_h2 = pd.DataFrame({
        "kamis_smooth": [pred_h1],
        "lag1": [pred_h1],
        "lag2": [lag1],
        "lag3": [lag2],
        "county_norm": [c],
    })
    pred_h2 = model.predict(X_h2)[0]

    future_rows.append({
        "county": c,
        "last_obs_week": last_week,
        "horizon1_date": h1_date,
        "agr_pred_h1": pred_h1,
        "horizon2_date": h2_date,
        "agr_pred_h2": pred_h2,
    })

future_df = pd.DataFrame(future_rows)
future_df



target_counties = ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]
panel_five = panel[panel["county_norm"].isin(target_counties)].copy()

# ---- 3. Create lags and training set ----
panel_five = panel_five.sort_values(["county_norm", "week_start"])

# ---- Recursive forecasts up to 2025-12-01 ----
target_start = pd.Timestamp("2025-12-08")
target_end   = pd.Timestamp("2025-12-15")

forecast_rows = []

# Determine the global last observed week in the aligned panel
global_last_week = panel_five["week_start"].max()

for c in ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]:
    hist = panel_five[panel_five["county_norm"] == c].sort_values("week_start")
    if hist.empty:
        continue

    last3 = hist["kamis_smooth"].tail(3).values
    if len(last3) == 1:
        lag1 = lag2 = lag3 = last3[-1]
    elif len(last3) == 2:
        lag1 = last3[-1]
        lag2 = lag3 = last3[-2]
    else:
        lag1 = last3[-1]
        lag2 = last3[-2]
        lag3 = last3[-3]

    current_week = global_last_week

    while current_week < target_end:
        next_week = current_week + timedelta(days=7)
        X_h = pd.DataFrame({
            "kamis_smooth": [lag1],
            "lag1": [lag1],
            "lag2": [lag2],
            "lag3": [lag3],
            "county_norm": [c]
        })
        pred_h = model.predict(X_h)[0]

        forecast_rows.append({
            "county": c,
            "week_start": next_week,
            "agr_pred": pred_h
        })

        lag3 = lag2
        lag2 = lag1
        lag1 = pred_h
        current_week = next_week

forecast_df = pd.DataFrame(forecast_rows)

# Filter only weeks 2025-11-24 and 2025-12-01
mask = forecast_df["week_start"].isin([target_start, target_end])
forecast_target = forecast_df[mask].copy()

forecast_target = forecast_target.sort_values(['week_start'])
forecast_target


# We have forecast_target from previous cell
# Build submission for weeks 48 and 49 (derived from the dates)

forecast_target["week"] = forecast_target["week_start"].dt.isocalendar().week.astype(int)
forecast_target["ID"] = forecast_target["county"] + "_Week_" + forecast_target["week"].astype(str)
forecast_target["Target_RMSE"] = forecast_target["agr_pred"]
forecast_target["Target_MAE"] = forecast_target["agr_pred"]

submission = forecast_target[["ID", "Target_RMSE", "Target_MAE"]].reset_index(drop=True)


submission
# Out:
# Train MAE: 3.8259202396695455
# Train RMSE: 4.76112693098381
#                     ID  Target_RMSE  Target_MAE
# 0       Kiambu_Week_50    36.862253   36.862253
# 1    Kirinyaga_Week_50    39.107655   39.107655
# 2      Mombasa_Week_50    36.862253   36.862253
# 3      Nairobi_Week_50    33.855291   33.855291
# 4  Uasin-Gishu_Week_50    37.209958   37.209958
# 5       Kiambu_Week_51    36.862252   36.862252
# 6    Kirinyaga_Week_51    39.107655   39.107655
# 7      Mombasa_Week_51    36.862252   36.862252
# 8      Nairobi_Week_51    33.855291   33.855291
# 9  Uasin-Gishu_Week_51    37.209957   37.209957

# %%
submission.to_csv("submission.csv", index=False)

# %%
## Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings('ignore')


## Load the data
kamis_df = pd.read_csv('/content/kamis_maize_prices.csv')
agri_df = pd.read_csv('/content/agriBORA_maize_prices.csv')
week469 = pd.read_csv('/content/agriBORA_maize_prices_weeks_46_to_49.csv')


kamis_df.head()


agri_df.head()


# Selecting all entries with White Maize
kdf = kamis_df[kamis_df['Commodity_Classification'].str.contains("White_Maize", na=False)].copy()


kdf.head(5)


## Selecting all entries in the agriBORA set with White Maize (all the data)
agri_df = agri_df[agri_df['Commodity_Classification'].str.contains("White_Maize", na=False)].copy()
agri_df.shape


## The unique counties in the agriBORA dataset
agri_df.County.unique()


## The unique counties in the KAMIS dataset
kdf.County.unique()


## The counties of interest
target_counties = {"Kiambu","Kirinyaga","Mombasa","Nairobi","Uasin-Gishu"}


## Restricting myself to target counties
kdf = kdf[kdf['County'].isin(target_counties)]
agri_df = agri_df[agri_df['County'].isin(target_counties)]


## Select the price columns (Wholesale)
kdf['price'] = pd.to_numeric(kdf['Wholesale'], errors='coerce')
agri_df['price'] = pd.to_numeric(agri_df['WholeSale'], errors='coerce')


## Convert Date to datetime object
kdf['Date'] = pd.to_datetime(kdf['Date'])
agri_df['Date'] = pd.to_datetime(agri_df['Date'])


# Weekly alignment (use Monday as start of ISO week)
agri_df["week"] = agri_df["Date"].dt.to_period("W").apply(lambda p: p.start_time)
kdf["week"] = kdf["Date"].dt.to_period("W").apply(lambda p: p.start_time)


agri_df.head()


## Aggregate to Count-Week wholesale mean
kdf_week = (
    kdf.groupby(['County', 'week'], as_index=False)['price']
    .mean()
    .rename(columns={'price' : 'kamis_price'})
)

agri_df_week = (
    agri_df.groupby(['County', 'week'], as_index=False)['price']
    .mean()
    .rename(columns={'price': 'agri_price'})
)


kdf_week.head()


agri_df_week.head()


## How many weeks of data is covered in each table ?

coverage_agr = (agri_df_week.groupby("County")["week"]
           .agg(min_date="min", max_date="max", weeks="nunique")
           .reset_index())
coverage_agr["dataset"] = "agribora"

coverage_kam = (kdf_week.groupby("County")["week"]
           .agg(min_date="min", max_date="max", weeks="nunique")
           .reset_index())
coverage_kam["dataset"] = "kamis"


coverage = pd.concat([coverage_agr, coverage_kam], ignore_index=True)


coverage


#



# Is there an overlap between kamis & agribora data ?
overlap = (
    agri_df_week.merge(kdf_week, on=['County', 'week'], how='inner')
    .sort_values(['County', 'week'])
)


overlap


# Ensure 'week' is datetime or sortable
overlap['week'] = pd.to_datetime(overlap['week'])

# Set style


# List of counties
counties = overlap['County'].unique()





## Do some stats if the overlap is not empty

if not overlap.empty:
    overlap["diff"] = overlap["agri_price"] - overlap["kamis_price"]
    stats = overlap.groupby("County").agg(
        n=("agri_price","size"),
        corr=("agri_price", lambda x: np.corrcoef(x, overlap.loc[x.index,"kamis_price"])[0,1] if len(x)>2 else np.nan),
        mean_bias=("diff","mean"),
        mae=("diff", lambda x: np.abs(x).mean())
    ).reset_index().round(3)
else:
    stats = pd.DataFrame(columns=["county_norm","n","corr","mean_bias","mae"])


stats


agri_df_week.shape, kdf_week.shape


### Forecast idea

## Back kdf_week & agri_df_week
kdf_week.head()


agri_df_week.head()



## Another Idea


agr = pd.read_csv("/content/agriBORA_maize_prices.csv", parse_dates=["Date"])
kamis = pd.read_csv("/content/kamis_maize_prices.csv", parse_dates=["Date"])

agr = pd.concat([agr, week469], ignore_index=True)

agr = pd.read_csv("/content/agriBORA_maize_prices.csv", parse_dates=["Date"])

# Filter to white maize
agr = agr[agr["Commodity_Classification"].str.contains("White_Maize", na=False)].copy()
kamis = kamis[kamis["Commodity_Classification"].str.contains("White_Maize", na=False)].copy()

def norm_county(s):
    return s.strip() if isinstance(s, str) else s

agr["county_norm"] = agr["County"].apply(norm_county)
kamis["county_norm"] = kamis["County"].apply(norm_county)

target_counties = ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]
agr = agr[agr["county_norm"].isin(target_counties)].copy()
kamis = kamis[kamis["county_norm"].isin(target_counties)].copy()

# Weekly aggregation
agr["week_start"] = agr["Date"].dt.to_period("W").apply(lambda p: p.start_time)
kamis["week_start"] = kamis["Date"].dt.to_period("W").apply(lambda p: p.start_time)

agr["agr_price"] = pd.to_numeric(agr["WholeSale"], errors="coerce")
kamis["kamis_price"] = pd.to_numeric(kamis["Wholesale"], errors="coerce")

agr_week = agr.groupby(["county_norm", "week_start"], as_index=False)["agr_price"].mean()
kamis_week = kamis.groupby(["county_norm", "week_start"], as_index=False)["kamis_price"].mean()


kamis_week.head()


# Kenyan county centroid coordinates (approximate)
# Source: Public GIS datasets / government county shapefiles (preloaded here manually)
data = {
    "county_norm": [
        "Baringo", "Bomet", "Bungoma", "Busia", "Elgeyo-Marakwet", "Embu",
        "Garissa", "Homa Bay", "Isiolo", "Kajiado", "Kakamega", "Kericho",
        "Kiambu", "Kilifi", "Kirinyaga", "Kisii", "Kisumu", "Kitui",
        "Kwale", "Laikipia", "Lamu", "Machakos", "Makueni", "Mandera",
        "Marsabit", "Meru", "Migori", "Mombasa", "Murang'a", "Nairobi",
        "Nakuru", "Nandi", "Narok", "Nyamira", "Nyandarua", "Nyeri",
        "Samburu", "Siaya", "Taita-Taveta", "Tana River", "Tharaka-Nithi",
        "Trans Nzoia", "Turkana", "Uasin-Gishu", "Vihiga", "Wajir", "West Pokot"
    ],
    "latitude": [
        0.469, -0.801, 0.569, 0.434, 1.046, -0.531,
        -0.453, -0.495, 0.352, -2.098, 0.307, -0.377,
        -1.030, -3.510, -0.498, -0.681, -0.091, -1.366,
        -4.175, 0.421, -2.162, -1.517, -2.247, 3.937,
        3.544, 0.355, -1.064, -4.043, -0.783, -1.286,
        -0.303, 0.205, -1.145, -0.566, -0.258, -0.419,
        0.993, -0.133, -3.316, -1.845, -0.283, 1.010,
        3.118, 0.539, 0.023, 1.748, 1.532
    ],
    "longitude": [
        35.990, 35.342, 34.564, 34.124, 35.363, 37.456,
        39.654, 34.639, 38.570, 36.789, 34.751, 35.279,
        36.868, 39.800, 37.318, 34.778, 34.761, 38.015,
        39.458, 36.787, 40.902, 37.263, 37.892, 41.847,
        37.998, 37.655, 34.473, 39.668, 36.605, 36.816,
        36.188, 35.117, 35.860, 34.935, 36.574, 36.947,
        37.537, 34.266, 37.757, 39.507, 37.908, 35.021,
        35.587, 35.283, 34.729, 40.060, 35.162
    ]
}

centroids = pd.DataFrame(data)
centroids.head()


present_counties = kamis_week["county_norm"].unique().tolist()
centroids = centroids[centroids["county_norm"].isin(present_counties)].reset_index(drop=True)

# Haversine distance function
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# Compute full distance matrix
counties = centroids["county_norm"].tolist()
dist_matrix = pd.DataFrame(np.zeros((len(counties), len(counties))),
                           index=counties, columns=counties)

for i, c1 in centroids.iterrows():
    for j, c2 in centroids.iterrows():
        dist_matrix.loc[c1["county_norm"], c2["county_norm"]] = haversine(
            c1["latitude"], c1["longitude"],
            c2["latitude"], c2["longitude"]
        )

# Compute nearest 3 neighbours for each county
nearest = {}
for c in counties:
    sorted_nei = dist_matrix.loc[c].sort_values()
    nearest[c] = list(sorted_nei.index[1:4])  # Skip itself at index 0

nearest_df = pd.DataFrame({
    "county": counties,
    "nearest_1": [nearest[c][0] for c in counties],
    "nearest_2": [nearest[c][1] for c in counties],
    "nearest_3": [nearest[c][2] for c in counties],
})

dist_matrix.shape


dist_matrix


nearest_df.head()


## Let see which counties are closest to our target_counties
closest_to_target = nearest_df[nearest_df["county"].isin(target_counties)]
closest_to_target


# --------------------------------------------
#   BUILD CLEAN WEEKLY PANEL PER COUNTY
#    (gap-filling + smoothing)
# --------------------------------------------

all_panels = []

for c in target_counties:
    sub = kamis_week[kamis_week["county_norm"] == c].copy()
    if sub.empty:
        continue

    # Continuous weekly index from first to last observed for that county
    min_d = sub["week_start"].min()
    max_d = sub["week_start"].max()
    full_weeks = pd.date_range(min_d, max_d, freq="W-MON")

    df = pd.DataFrame({"week_start": full_weeks})
    df["county_norm"] = c

    df = df.merge(sub[["week_start", "kamis_price"]],
                  on="week_start", how="left")

    # Fill missing KAMIS prices within that county
    df["kamis_price"] = df["kamis_price"].ffill().bfill()

    # 3-week rolling mean smoothing
    df["kamis_smooth"] = df["kamis_price"].rolling(3, min_periods=1).mean()

    all_panels.append(df)

kamis_panel = pd.concat(all_panels, ignore_index=True)

# Merge with Agribora weekly prices
panel = kamis_panel.merge(
    agr_week,
    on=["county_norm", "week_start"],
    how="left"
)

# --------------------------------------------
#  CREATE LAGS & TRAINING SET (H+1 MODEL)
# --------------------------------------------

panel = panel.sort_values(["county_norm", "week_start"])

for lag in [1, 2, 3]:
    panel[f"lag{lag}"] = panel.groupby("county_norm")["kamis_smooth"].shift(lag)

# Drop rows with missing lags or missing Agribora price
panel_train = panel.dropna(subset=["lag1", "lag2", "lag3", "agr_price"]).reset_index(drop=True)

X = panel_train[["kamis_smooth", "lag1", "lag2", "lag3", "county_norm"]]
y = panel_train["agr_price"]

# --------------------------------------------
#  UNIFIED SINGLE ML MODEL (ElasticNet)
# --------------------------------------------

numeric_features     = ["kamis_smooth", "lag1", "lag2", "lag3"]
categorical_features = ["county_norm"]

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

enet = ElasticNet(alpha=0.05, l1_ratio=0.2, random_state=42)

model = Pipeline(steps=[
    ("prep", preprocess),
    ("model", enet)
])

model.fit(X, y)

# Optionally inspect training fit quality:
y_pred_train = model.predict(X)
print("Train MAE:", mean_absolute_error(y, y_pred_train))
print("Train RMSE:", np.sqrt(mean_squared_error(y, y_pred_train)))

# --------------------------------------------
#  FORECAST H+1 AND H+2 FOR EACH COUNTY
#    using recursive prediction
# --------------------------------------------

future_rows = []

for c in target_counties:
    hist = panel[panel["county_norm"] == c].sort_values("week_start").copy()
    if hist.empty:
        continue

    # Last three smoothed KAMIS prices (after filling + smoothing)
    last3 = hist["kamis_smooth"].tail(3).values

    # Ensure we have 3 values (fall back if series shorter)
    if len(last3) == 1:
        lag1 = lag2 = lag3 = last3[-1]
    elif len(last3) == 2:
        lag1 = last3[-1]
        lag2 = lag3 = last3[-2]
    else:
        lag1 = last3[-1]
        lag2 = last3[-2]
        lag3 = last3[-3]

    last_week = hist["week_start"].max()

    # --- Horizon 1 (next week) ---
    h1_date = last_week + timedelta(days=7)
    X_h1 = pd.DataFrame({
        "kamis_smooth": [lag1],  # use last known smooth KAMIS as base
        "lag1": [lag1],
        "lag2": [lag2],
        "lag3": [lag3],
        "county_norm": [c],
    })
    pred_h1 = model.predict(X_h1)[0]

    # --- Horizon 2 (two weeks ahead) ---
    h2_date = h1_date + timedelta(days=7)
    # For h+2, treat h+1 prediction as the new "current" level
    X_h2 = pd.DataFrame({
        "kamis_smooth": [pred_h1],
        "lag1": [pred_h1],
        "lag2": [lag1],
        "lag3": [lag2],
        "county_norm": [c],
    })
    pred_h2 = model.predict(X_h2)[0]

    future_rows.append({
        "county": c,
        "last_obs_week": last_week,
        "horizon1_date": h1_date,
        "agr_pred_h1": pred_h1,
        "horizon2_date": h2_date,
        "agr_pred_h2": pred_h2,
    })

future_df = pd.DataFrame(future_rows)
future_df



target_counties = ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]
panel_five = panel[panel["county_norm"].isin(target_counties)].copy()

# ---- 3. Create lags and training set ----
panel_five = panel_five.sort_values(["county_norm", "week_start"])

# ---- Recursive forecasts up to 2025-12-01 ----
target_start = pd.Timestamp("2025-12-08")
target_end   = pd.Timestamp("2025-12-15")

forecast_rows = []

# Determine the global last observed week in the aligned panel
global_last_week = panel_five["week_start"].max()

for c in ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]:
    hist = panel_five[panel_five["county_norm"] == c].sort_values("week_start")
    if hist.empty:
        continue

    last3 = hist["kamis_smooth"].tail(3).values
    if len(last3) == 1:
        lag1 = lag2 = lag3 = last3[-1]
    elif len(last3) == 2:
        lag1 = last3[-1]
        lag2 = lag3 = last3[-2]
    else:
        lag1 = last3[-1]
        lag2 = last3[-2]
        lag3 = last3[-3]

    current_week = global_last_week

    while current_week < target_end:
        next_week = current_week + timedelta(days=7)
        X_h = pd.DataFrame({
            "kamis_smooth": [lag1],
            "lag1": [lag1],
            "lag2": [lag2],
            "lag3": [lag3],
            "county_norm": [c]
        })
        pred_h = model.predict(X_h)[0]

        forecast_rows.append({
            "county": c,
            "week_start": next_week,
            "agr_pred": pred_h
        })

        lag3 = lag2
        lag2 = lag1
        lag1 = pred_h
        current_week = next_week

forecast_df = pd.DataFrame(forecast_rows)

# Filter only weeks 2025-11-24 and 2025-12-01
mask = forecast_df["week_start"].isin([target_start, target_end])
forecast_target = forecast_df[mask].copy()

forecast_target = forecast_target.sort_values(['week_start'])
forecast_target


# We have forecast_target from previous cell
# Build submission for weeks 48 and 49 (derived from the dates)

forecast_target["week"] = forecast_target["week_start"].dt.isocalendar().week.astype(int)
forecast_target["ID"] = forecast_target["county"] + "_Week_" + forecast_target["week"].astype(str)
forecast_target["Target_RMSE"] = forecast_target["agr_pred"]
forecast_target["Target_MAE"] = forecast_target["agr_pred"]

submission = forecast_target[["ID", "Target_RMSE", "Target_MAE"]].reset_index(drop=True)


submission





# Load the submission template
samp_sub = pd.read_csv('/content/SampleSubmission (2).csv')

# Extract the week number from the 'ID' column in the template
samp_sub['week'] = samp_sub['ID'].apply(lambda x: int(x.split('_Week_')[-1]))

# Filter the template to get only the weeks we need to add (Weeks 52, 1, and 2).
# Weeks 50 and 51 are already in our current `submission` with predicted values.
weeks_to_add_from_template = samp_sub[samp_sub['week'].isin([52, 1, 2])].copy()

# Ensure the current submission DataFrame's 'week' column is correctly set
# This overwrites any previous inconsistent 'week' column data
submission['week'] = submission['ID'].apply(lambda x: int(x.split('_Week_')[-1]))

# Concatenate the current submission with the filtered template entries
# We drop the 'week' column from the template before concatenating to avoid duplicate columns and ensure our 'week' column in 'submission' remains canonical
submission = pd.concat([
    submission,
    weeks_to_add_from_template.drop(columns=['week'])
], ignore_index=True)

# Remove any duplicated IDs, keeping the first occurrence (which would be our predictions for Week 50/51 if they exist, or the template for Week 52/1/2)
submission.drop_duplicates(subset=['ID'], inplace=True)

# Sort the submission for better readability
submission = submission.sort_values(by=['ID']).reset_index(drop=True)

print("Final Submission DataFrame with all required weeks:")
display(submission)

# Save the final submission to a CSV file
submission_path = "submission.csv"
submission.to_csv(submission_path, index=False)
print(f"Corrected submission file saved as '{submission_path}'.")
# Out:
# Train MAE: 3.8259202396695455
# Train RMSE: 4.76112693098381
# Final Submission DataFrame with all required weeks:
#                      ID  Target_RMSE  Target_MAE  week
# 0         Kiambu_Week_1     0.000000    0.000000   NaN
# 1         Kiambu_Week_2     0.000000    0.000000   NaN
# 2        Kiambu_Week_50    36.862253   36.862253  50.0
# 3        Kiambu_Week_51    36.862252   36.862252  51.0
# 4        Kiambu_Week_52     0.000000    0.000000   NaN
# 5      Kirinyaga_Week_1     0.000000    0.000000   NaN
# 6      Kirinyaga_Week_2     0.000000    0.000000   NaN
# 7     Kirinyaga_Week_50    39.107655   39.107655  50.0
# 8     Kirinyaga_Week_51    39.107655   39.107655  51.0
# 9     Kirinyaga_Week_52     0.000000    0.000000   NaN
# 10       Mombasa_Week_1     0.000000    0.000000   NaN
# 11       Mombasa_Week_2     0.000000    0.000000   NaN
# 12      Mombasa_Week_50    36.862253   36.862253  50.0
# 13      Mombasa_Week_51    36.862252   36.862252  51.0
# 14      Mombasa_Week_52     0.000000    0.000000   NaN
# 15       Nairobi_Week_1     0.000000    0.000000   NaN
# 16       Nairobi_Week_2     0.000000    0.000000   NaN
# 17      Nairobi_Week_50    33.855291   33.855291  50.0
# 18      Nairobi_Week_51    33.855291   33.855291  51.0
# 19      Nairobi_Week_52     0.000000    0.000000   NaN
# 20   Uasin-Gishu_Week_1     0.000000    0.000000   NaN
# 21   Uasin-Gishu_Week_2     0.000000    0.000000   NaN
# 22  Uasin-Gishu_Week_50    37.209958   37.209958  50.0
# 23  Uasin-Gishu_Week_51    37.209957   37.209957  51.0
# 24  Uasin-Gishu_Week_52     0.000000    0.000000   NaN
# Corrected submission file saved as 'submission.csv'.

# %%
submission_path = "submission.csv"
submission.to_csv(submission_path, index=False)

# %%
## Import libraries
import pandas as pd
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error

import warnings
warnings.filterwarnings('ignore')


## Load the data
kamis_df = pd.read_csv('/content/kamis_maize_prices.csv')
agri_df = pd.read_csv('/content/agriBORA_maize_prices.csv')
week469 = pd.read_csv('/content/agriBORA_maize_prices_weeks_46_to_49.csv')


kamis_df.head()


agri_df.head()


# Selecting all entries with White Maize
kdf = kamis_df[kamis_df['Commodity_Classification'].str.contains("White_Maize", na=False)].copy()


kdf.head(5)


## Selecting all entries in the agriBORA set with White Maize (all the data)
agri_df = agri_df[agri_df['Commodity_Classification'].str.contains("White_Maize", na=False)].copy()
agri_df.shape


## The unique counties in the agriBORA dataset
agri_df.County.unique()


## The unique counties in the KAMIS dataset
kdf.County.unique()


## The counties of interest
target_counties = {"Kiambu","Kirinyaga","Mombasa","Nairobi","Uasin-Gishu"}


## Restricting myself to target counties
kdf = kdf[kdf['County'].isin(target_counties)]
agri_df = agri_df[agri_df['County'].isin(target_counties)]


## Select the price columns (Wholesale)
kdf['price'] = pd.to_numeric(kdf['Wholesale'], errors='coerce')
agri_df['price'] = pd.to_numeric(agri_df['WholeSale'], errors='coerce')


## Convert Date to datetime object
kdf['Date'] = pd.to_datetime(kdf['Date'])
agri_df['Date'] = pd.to_datetime(agri_df['Date'])


# Weekly alignment (use Monday as start of ISO week)
agri_df["week"] = agri_df["Date"].dt.to_period("W").apply(lambda p: p.start_time)
kdf["week"] = kdf["Date"].dt.to_period("W").apply(lambda p: p.start_time)


agri_df.head()


## Aggregate to Count-Week wholesale mean
kdf_week = (
    kdf.groupby(['County', 'week'], as_index=False)['price']
    .mean()
    .rename(columns={'price' : 'kamis_price'})
)

agri_df_week = (
    agri_df.groupby(['County', 'week'], as_index=False)['price']
    .mean()
    .rename(columns={'price': 'agri_price'})
)


kdf_week.head()


agri_df_week.head()


## How many weeks of data is covered in each table ?

coverage_agr = (agri_df_week.groupby("County")["week"]
           .agg(min_date="min", max_date="max", weeks="nunique")
           .reset_index())
coverage_agr["dataset"] = "agribora"

coverage_kam = (kdf_week.groupby("County")["week"]
           .agg(min_date="min", max_date="max", weeks="nunique")
           .reset_index())
coverage_kam["dataset"] = "kamis"


coverage = pd.concat([coverage_agr, coverage_kam], ignore_index=True)


coverage


#



# Is there an overlap between kamis & agribora data ?
overlap = (
    agri_df_week.merge(kdf_week, on=['County', 'week'], how='inner')
    .sort_values(['County', 'week'])
)


overlap


# Ensure 'week' is datetime or sortable
overlap['week'] = pd.to_datetime(overlap['week'])

# Set style


# List of counties
counties = overlap['County'].unique()





## Do some stats if the overlap is not empty

if not overlap.empty:
    overlap["diff"] = overlap["agri_price"] - overlap["kamis_price"]
    stats = overlap.groupby("County").agg(
        n=("agri_price","size"),
        corr=("agri_price", lambda x: np.corrcoef(x, overlap.loc[x.index,"kamis_price"])[0,1] if len(x)>2 else np.nan),
        mean_bias=("diff","mean"),
        mae=("diff", lambda x: np.abs(x).mean())
    ).reset_index().round(3)
else:
    stats = pd.DataFrame(columns=["county_norm","n","corr","mean_bias","mae"])


stats


agri_df_week.shape, kdf_week.shape


### Forecast idea

## Back kdf_week & agri_df_week
kdf_week.head()


agri_df_week.head()



## Another Idea


agr = pd.read_csv("/content/agriBORA_maize_prices.csv", parse_dates=["Date"])
kamis = pd.read_csv("/content/kamis_maize_prices.csv", parse_dates=["Date"])

agr = pd.concat([agr, week469], ignore_index=True)

agr = pd.read_csv("/content/agriBORA_maize_prices.csv", parse_dates=["Date"])

# Filter to white maize
agr = agr[agr["Commodity_Classification"].str.contains("White_Maize", na=False)].copy()
kamis = kamis[kamis["Commodity_Classification"].str.contains("White_Maize", na=False)].copy()

def norm_county(s):
    return s.strip() if isinstance(s, str) else s

agr["county_norm"] = agr["County"].apply(norm_county)
kamis["county_norm"] = kamis["County"].apply(norm_county)

target_counties = ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]
agr = agr[agr["county_norm"].isin(target_counties)].copy()
kamis = kamis[kamis["county_norm"].isin(target_counties)].copy()

# Weekly aggregation
agr["week_start"] = agr["Date"].dt.to_period("W").apply(lambda p: p.start_time)
kamis["week_start"] = kamis["Date"].dt.to_period("W").apply(lambda p: p.start_time)

agr["agr_price"] = pd.to_numeric(agr["WholeSale"], errors="coerce")
kamis["kamis_price"] = pd.to_numeric(kamis["Wholesale"], errors="coerce")

agr_week = agr.groupby(["county_norm", "week_start"], as_index=False)["agr_price"].mean()
kamis_week = kamis.groupby(["county_norm", "week_start"], as_index=False)["kamis_price"].mean()


kamis_week.head()


# Kenyan county centroid coordinates (approximate)
# Source: Public GIS datasets / government county shapefiles (preloaded here manually)
data = {
    "county_norm": [
        "Baringo", "Bomet", "Bungoma", "Busia", "Elgeyo-Marakwet", "Embu",
        "Garissa", "Homa Bay", "Isiolo", "Kajiado", "Kakamega", "Kericho",
        "Kiambu", "Kilifi", "Kirinyaga", "Kisii", "Kisumu", "Kitui",
        "Kwale", "Laikipia", "Lamu", "Machakos", "Makueni", "Mandera",
        "Marsabit", "Meru", "Migori", "Mombasa", "Murang'a", "Nairobi",
        "Nakuru", "Nandi", "Narok", "Nyamira", "Nyandarua", "Nyeri",
        "Samburu", "Siaya", "Taita-Taveta", "Tana River", "Tharaka-Nithi",
        "Trans Nzoia", "Turkana", "Uasin-Gishu", "Vihiga", "Wajir", "West Pokot"
    ],
    "latitude": [
        0.469, -0.801, 0.569, 0.434, 1.046, -0.531,
        -0.453, -0.495, 0.352, -2.098, 0.307, -0.377,
        -1.030, -3.510, -0.498, -0.681, -0.091, -1.366,
        -4.175, 0.421, -2.162, -1.517, -2.247, 3.937,
        3.544, 0.355, -1.064, -4.043, -0.783, -1.286,
        -0.303, 0.205, -1.145, -0.566, -0.258, -0.419,
        0.993, -0.133, -3.316, -1.845, -0.283, 1.010,
        3.118, 0.539, 0.023, 1.748, 1.532
    ],
    "longitude": [
        35.990, 35.342, 34.564, 34.124, 35.363, 37.456,
        39.654, 34.639, 38.570, 36.789, 34.751, 35.279,
        36.868, 39.800, 37.318, 34.778, 34.761, 38.015,
        39.458, 36.787, 40.902, 37.263, 37.892, 41.847,
        37.998, 37.655, 34.473, 39.668, 36.605, 36.816,
        36.188, 35.117, 35.860, 34.935, 36.574, 36.947,
        37.537, 34.266, 37.757, 39.507, 37.908, 35.021,
        35.587, 35.283, 34.729, 40.060, 35.162
    ]
}

centroids = pd.DataFrame(data)
centroids.head()


present_counties = kamis_week["county_norm"].unique().tolist()
centroids = centroids[centroids["county_norm"].isin(present_counties)].reset_index(drop=True)

# Haversine distance function
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # km
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat/2)**2 + np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# Compute full distance matrix
counties = centroids["county_norm"].tolist()
dist_matrix = pd.DataFrame(np.zeros((len(counties), len(counties))),
                           index=counties, columns=counties)

for i, c1 in centroids.iterrows():
    for j, c2 in centroids.iterrows():
        dist_matrix.loc[c1["county_norm"], c2["county_norm"]] = haversine(
            c1["latitude"], c1["longitude"],
            c2["latitude"], c2["longitude"]
        )

# Compute nearest 3 neighbours for each county
nearest = {}
for c in counties:
    sorted_nei = dist_matrix.loc[c].sort_values()
    nearest[c] = list(sorted_nei.index[1:4])  # Skip itself at index 0

nearest_df = pd.DataFrame({
    "county": counties,
    "nearest_1": [nearest[c][0] for c in counties],
    "nearest_2": [nearest[c][1] for c in counties],
    "nearest_3": [nearest[c][2] for c in counties],
})

dist_matrix.shape


dist_matrix


nearest_df.head()


## Let see which counties are closest to our target_counties
closest_to_target = nearest_df[nearest_df["county"].isin(target_counties)]
closest_to_target


# --------------------------------------------
#   BUILD CLEAN WEEKLY PANEL PER COUNTY
#    (gap-filling + smoothing)
# --------------------------------------------

all_panels = []

for c in target_counties:
    sub = kamis_week[kamis_week["county_norm"] == c].copy()
    if sub.empty:
        continue

    # Continuous weekly index from first to last observed for that county
    min_d = sub["week_start"].min()
    max_d = sub["week_start"].max()
    full_weeks = pd.date_range(min_d, max_d, freq="W-MON")

    df = pd.DataFrame({"week_start": full_weeks})
    df["county_norm"] = c

    df = df.merge(sub[["week_start", "kamis_price"]],
                  on="week_start", how="left")

    # Fill missing KAMIS prices within that county
    df["kamis_price"] = df["kamis_price"].ffill().bfill()

    # 3-week rolling mean smoothing
    df["kamis_smooth"] = df["kamis_price"].rolling(3, min_periods=1).mean()

    all_panels.append(df)

kamis_panel = pd.concat(all_panels, ignore_index=True)

# Merge with Agribora weekly prices
panel = kamis_panel.merge(
    agr_week,
    on=["county_norm", "week_start"],
    how="left"
)

# --------------------------------------------
#  CREATE LAGS & TRAINING SET (H+1 MODEL)
# --------------------------------------------

panel = panel.sort_values(["county_norm", "week_start"])

for lag in [1, 2, 3]:
    panel[f"lag{lag}"] = panel.groupby("county_norm")["kamis_smooth"].shift(lag)

# Drop rows with missing lags or missing Agribora price
panel_train = panel.dropna(subset=["lag1", "lag2", "lag3", "agr_price"]).reset_index(drop=True)

X = panel_train[["kamis_smooth", "lag1", "lag2", "lag3", "county_norm"]]
y = panel_train["agr_price"]

# %%
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
#  UNIFIED SINGLE ML MODEL (ElasticNet)
# --------------------------------------------

numeric_features     = ["kamis_smooth", "lag1", "lag2", "lag3"]
categorical_features = ["county_norm"]

numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

categorical_transformer = OneHotEncoder(handle_unknown="ignore")

preprocess = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

enet = ElasticNet(alpha=0.05, l1_ratio=0.2, random_state=42)

model = Pipeline(steps=[
    ("prep", preprocess),
    ("model", enet)
])

model.fit(X, y)

# Optionally inspect training fit quality:
y_pred_train = model.predict(X)
print("Train MAE:", mean_absolute_error(y, y_pred_train))
print("Train RMSE:", np.sqrt(mean_squared_error(y, y_pred_train)))
# Out:
# Train MAE: 3.8259202396695455
# Train RMSE: 4.76112693098381

# %%
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# -----------------------------
# Prepare folds
# -----------------------------
kf = KFold(n_splits=5, shuffle=True, random_state=42)
X = X.copy()  # ensure no inplace issues
y = y.copy()

# Out-of-fold predictions for stacking
X["ridge_oof"] = 0.0
X["enet_oof"] = 0.0

ridge_test_preds = np.zeros(len(X))
enet_test_preds = np.zeros(len(X))

# -----------------------------
# Level-1: Ridge
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold, y_val_fold = y.iloc[trn_idx], y.iloc[val_idx]

    ridge_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", Ridge(alpha=10.0))
    ])
    ridge_model.fit(X_train_fold, y_train_fold)

    X.loc[val_idx, "ridge_oof"] = ridge_model.predict(X_val_fold)
    ridge_test_preds += ridge_model.predict(X) / 5

# -----------------------------
# Level-1: ElasticNet
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold, y_val_fold = y.iloc[trn_idx], y.iloc[val_idx]

    enet_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", ElasticNet(alpha=0.05, l1_ratio=0.2, random_state=42))
    ])
    enet_model.fit(X_train_fold, y_train_fold)

    X.loc[val_idx, "enet_oof"] = enet_model.predict(X_val_fold)
    enet_test_preds += enet_model.predict(X) / 5

# -----------------------------
# Level-2 meta model
# -----------------------------
stack_features = ["ridge_oof", "enet_oof"]
X_stack = X[stack_features]

meta_model = Ridge(alpha=5.0)
meta_model.fit(X_stack, y)

# Final predictions
final_preds = meta_model.predict(X_stack)

# -----------------------------
# Evaluate training fit
# -----------------------------
print("Train MAE:", mean_absolute_error(y, final_preds))
print("Train RMSE:", np.sqrt(mean_squared_error(y, final_preds)))
# Out:
# Train MAE: 3.942509198860035
# Train RMSE: 4.876446301711172

# %%
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
from statsmodels.tsa.ar_model import AutoReg

# -----------------------------
# Prepare folds
# -----------------------------
kf = KFold(n_splits=5, shuffle=True, random_state=42)
X = X.copy()
y = y.copy()

# -----------------------------
# OOF predictions for stacking
# -----------------------------
stack_models = ["ridge_oof", "enet_oof", "ar_oof", "rf_oof", "et_oof", "knn_oof", "gbr_oof"]
for m in stack_models:
    X[m] = 0.0

oof_preds = {m: np.zeros(len(X)) for m in stack_models}
test_preds = {m: np.zeros(len(X)) for m in stack_models}

# -----------------------------
# Level-1: Ridge
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold, y_val_fold = y.iloc[trn_idx], y.iloc[val_idx]

    ridge_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", Ridge(alpha=10.0))
    ])
    ridge_model.fit(X_train_fold, y_train_fold)
    X.loc[val_idx, "ridge_oof"] = ridge_model.predict(X_val_fold)
    oof_preds["ridge_oof"] += ridge_model.predict(X) / 5

# -----------------------------
# Level-1: ElasticNet
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold = y.iloc[trn_idx]

    enet_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", ElasticNet(alpha=0.05, l1_ratio=0.2, random_state=42))
    ])
    enet_model.fit(X_train_fold, y_train_fold)
    X.loc[val_idx, "enet_oof"] = enet_model.predict(X_val_fold)
    oof_preds["enet_oof"] += enet_model.predict(X) / 5

# -----------------------------
# Level-1: AutoReg
# -----------------------------
ar_features = ["kamis_smooth", "lag1", "lag2", "lag3"]
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    y_train_fold = y.iloc[trn_idx]
    y_val_fold = y.iloc[val_idx]

    ar_model = AutoReg(y_train_fold, lags=3, old_names=False)
    ar_res = ar_model.fit()
    pred_val = ar_res.predict(start=len(y_train_fold), end=len(y_train_fold)+len(y_val_fold)-1)
    X.loc[val_idx, "ar_oof"] = pred_val.values
    pred_full = ar_res.predict(start=0, end=len(y)-1)
    oof_preds["ar_oof"] += pred_full / 5

# -----------------------------
# Level-1: RandomForest
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold = y.iloc[trn_idx]

    rf_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", RandomForestRegressor(n_estimators=200, max_depth=5, random_state=42))
    ])
    rf_model.fit(X_train_fold, y_train_fold)
    X.loc[val_idx, "rf_oof"] = rf_model.predict(X_val_fold)
    oof_preds["rf_oof"] += rf_model.predict(X) / 5

# -----------------------------
# Level-1: ExtraTrees
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold = y.iloc[trn_idx]

    et_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", ExtraTreesRegressor(n_estimators=200, max_depth=5, random_state=42))
    ])
    et_model.fit(X_train_fold, y_train_fold)
    X.loc[val_idx, "et_oof"] = et_model.predict(X_val_fold)
    oof_preds["et_oof"] += et_model.predict(X) / 5

# -----------------------------
# Level-1: KNeighbors
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold = y.iloc[trn_idx]

    knn_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", KNeighborsRegressor(n_neighbors=5))
    ])
    knn_model.fit(X_train_fold, y_train_fold)
    X.loc[val_idx, "knn_oof"] = knn_model.predict(X_val_fold)
    oof_preds["knn_oof"] += knn_model.predict(X) / 5

# -----------------------------
# Level-1: GradientBoosting
# -----------------------------
for fold, (trn_idx, val_idx) in enumerate(kf.split(X)):
    X_train_fold, X_val_fold = X.iloc[trn_idx], X.iloc[val_idx]
    y_train_fold = y.iloc[trn_idx]

    gbr_model = Pipeline(steps=[
        ("prep", preprocess),
        ("model", GradientBoostingRegressor(n_estimators=200, max_depth=3, learning_rate=0.05, random_state=42))
    ])
    gbr_model.fit(X_train_fold, y_train_fold)
    X.loc[val_idx, "gbr_oof"] = gbr_model.predict(X_val_fold)
    oof_preds["gbr_oof"] += gbr_model.predict(X) / 5

# -----------------------------
# Level-2 to Level-7 stacking
# Use previous level OOF as features for next level
# -----------------------------
level_features = ["ridge_oof", "enet_oof", "ar_oof", "rf_oof", "et_oof", "knn_oof", "gbr_oof"]
for level in range(2, 8):
    meta_X = X[level_features]
    meta_model = Ridge(alpha=5.0)
    meta_model.fit(meta_X, y)
    X[f"level{level}_preds"] = meta_model.predict(meta_X)
    # add this level prediction to features for next level
    level_features.append(f"level{level}_preds")

# -----------------------------
# Final predictions (from last level)
# -----------------------------
final_preds = X[f"level7_preds"]

# -----------------------------
# Evaluate
# -----------------------------
print("Train MAE:", mean_absolute_error(y, final_preds))
print("Train RMSE:", np.sqrt(mean_squared_error(y, final_preds)))
# Out:
# Train MAE: 2.688428654116608
# Train RMSE: 3.5443390676659483

# %%
# --------------------------------------------
#  FORECAST H+1 AND H+2 FOR EACH COUNTY
#    using recursive prediction
# --------------------------------------------

future_rows = []

for c in target_counties:
    hist = panel[panel["county_norm"] == c].sort_values("week_start").copy()
    if hist.empty:
        continue

    # Last three smoothed KAMIS prices (after filling + smoothing)
    last3 = hist["kamis_smooth"].tail(3).values

    # Ensure we have 3 values (fall back if series shorter)
    if len(last3) == 1:
        lag1 = lag2 = lag3 = last3[-1]
    elif len(last3) == 2:
        lag1 = last3[-1]
        lag2 = lag3 = last3[-2]
    else:
        lag1 = last3[-1]
        lag2 = last3[-2]
        lag3 = last3[-3]

    last_week = hist["week_start"].max()

    # --- Horizon 1 (next week) ---
    h1_date = last_week + timedelta(days=7)
    X_h1 = pd.DataFrame({
        "kamis_smooth": [lag1],  # use last known smooth KAMIS as base
        "lag1": [lag1],
        "lag2": [lag2],
        "lag3": [lag3],
        "county_norm": [c],
    })
    pred_h1 = model.predict(X_h1)[0]

    # --- Horizon 2 (two weeks ahead) ---
    h2_date = h1_date + timedelta(days=7)
    # For h+2, treat h+1 prediction as the new "current" level
    X_h2 = pd.DataFrame({
        "kamis_smooth": [pred_h1],
        "lag1": [pred_h1],
        "lag2": [lag1],
        "lag3": [lag2],
        "county_norm": [c],
    })
    pred_h2 = model.predict(X_h2)[0]

    future_rows.append({
        "county": c,
        "last_obs_week": last_week,
        "horizon1_date": h1_date,
        "agr_pred_h1": pred_h1,
        "horizon2_date": h2_date,
        "agr_pred_h2": pred_h2,
    })

future_df = pd.DataFrame(future_rows)
future_df



target_counties = ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]
panel_five = panel[panel["county_norm"].isin(target_counties)].copy()

# ---- 3. Create lags and training set ----
panel_five = panel_five.sort_values(["county_norm", "week_start"])

# ---- Recursive forecasts up to 2025-12-01 ----
target_start = pd.Timestamp("2025-12-08")
target_end   = pd.Timestamp("2025-12-15")

forecast_rows = []

# Determine the global last observed week in the aligned panel
global_last_week = panel_five["week_start"].max()

for c in ["Kiambu", "Kirinyaga", "Mombasa", "Nairobi", "Uasin-Gishu"]:
    hist = panel_five[panel_five["county_norm"] == c].sort_values("week_start")
    if hist.empty:
        continue

    last3 = hist["kamis_smooth"].tail(3).values
    if len(last3) == 1:
        lag1 = lag2 = lag3 = last3[-1]
    elif len(last3) == 2:
        lag1 = last3[-1]
        lag2 = lag3 = last3[-2]
    else:
        lag1 = last3[-1]
        lag2 = last3[-2]
        lag3 = last3[-3]

    current_week = global_last_week

    while current_week < target_end:
        next_week = current_week + timedelta(days=7)
        X_h = pd.DataFrame({
            "kamis_smooth": [lag1],
            "lag1": [lag1],
            "lag2": [lag2],
            "lag3": [lag3],
            "county_norm": [c]
        })
        pred_h = model.predict(X_h)[0]

        forecast_rows.append({
            "county": c,
            "week_start": next_week,
            "agr_pred": pred_h
        })

        lag3 = lag2
        lag2 = lag1
        lag1 = pred_h
        current_week = next_week

forecast_df = pd.DataFrame(forecast_rows)

# Filter only weeks 2025-11-24 and 2025-12-01
mask = forecast_df["week_start"].isin([target_start, target_end])
forecast_target = forecast_df[mask].copy()

forecast_target = forecast_target.sort_values(['week_start'])
forecast_target


# We have forecast_target from previous cell
# Build submission for weeks 48 and 49 (derived from the dates)

forecast_target["week"] = forecast_target["week_start"].dt.isocalendar().week.astype(int)
forecast_target["ID"] = forecast_target["county"] + "_Week_" + forecast_target["week"].astype(str)
forecast_target["Target_RMSE"] = forecast_target["agr_pred"]
forecast_target["Target_MAE"] = forecast_target["agr_pred"]

submission = forecast_target[["ID", "Target_RMSE", "Target_MAE"]].reset_index(drop=True)


submission





# Load the submission template
samp_sub = pd.read_csv('/content/SampleSubmission (2).csv')

# Extract the week number from the 'ID' column in the template
samp_sub['week'] = samp_sub['ID'].apply(lambda x: int(x.split('_Week_')[-1]))

# Filter the template to get only the weeks we need to add (Weeks 52, 1, and 2).
# Weeks 50 and 51 are already in our current `submission` with predicted values.
weeks_to_add_from_template = samp_sub[samp_sub['week'].isin([52, 1, 2])].copy()

# Ensure the current submission DataFrame's 'week' column is correctly set
# This overwrites any previous inconsistent 'week' column data
submission['week'] = submission['ID'].apply(lambda x: int(x.split('_Week_')[-1]))

# Concatenate the current submission with the filtered template entries
# We drop the 'week' column from the template before concatenating to avoid duplicate columns and ensure our 'week' column in 'submission' remains canonical
submission = pd.concat([
    submission,
    weeks_to_add_from_template.drop(columns=['week'])
], ignore_index=True)

# Remove any duplicated IDs, keeping the first occurrence (which would be our predictions for Week 50/51 if they exist, or the template for Week 52/1/2)
submission.drop_duplicates(subset=['ID'], inplace=True)

# Sort the submission for better readability
submission = submission.sort_values(by=['ID']).reset_index(drop=True)

print("Final Submission DataFrame with all required weeks:")
display(submission)

# Save the final submission to a CSV file
submission_path = "submission.csv"
submission.to_csv(submission_path, index=False)
print(f"Corrected submission file saved as '{submission_path}'.")
# Out:
# Final Submission DataFrame with all required weeks:
#                      ID  Target_RMSE  Target_MAE  week
# 0         Kiambu_Week_1     0.000000    0.000000   NaN
# 1         Kiambu_Week_2     0.000000    0.000000   NaN
# 2        Kiambu_Week_50    36.690715   36.690715  50.0
# 3        Kiambu_Week_51    36.690714   36.690714  51.0
# 4        Kiambu_Week_52     0.000000    0.000000   NaN
# 5      Kirinyaga_Week_1     0.000000    0.000000   NaN
# 6      Kirinyaga_Week_2     0.000000    0.000000   NaN
# 7     Kirinyaga_Week_50    38.937091   38.937091  50.0
# 8     Kirinyaga_Week_51    38.937091   38.937091  51.0
# 9     Kirinyaga_Week_52     0.000000    0.000000   NaN
# 10       Mombasa_Week_1     0.000000    0.000000   NaN
# 11       Mombasa_Week_2     0.000000    0.000000   NaN
# 12      Mombasa_Week_50    36.690715   36.690715  50.0
# 13      Mombasa_Week_51    36.690714   36.690714  51.0
# 14      Mombasa_Week_52     0.000000    0.000000   NaN
# 15       Nairobi_Week_1     0.000000    0.000000   NaN
# 16       Nairobi_Week_2     0.000000    0.000000   NaN
# 17      Nairobi_Week_50    33.682449   33.682449  50.0
# 18      Nairobi_Week_51    33.682449   33.682449  51.0
# 19      Nairobi_Week_52     0.000000    0.000000   NaN
# 20   Uasin-Gishu_Week_1     0.000000    0.000000   NaN
# 21   Uasin-Gishu_Week_2     0.000000    0.000000   NaN
# 22  Uasin-Gishu_Week_50    37.038570   37.038570  50.0
# 23  Uasin-Gishu_Week_51    37.038570   37.038570  51.0
# 24  Uasin-Gishu_Week_52     0.000000    0.000000   NaN
# Corrected submission file saved as 'submission.csv'.

# %%
submission.to_csv(submission_path, index=False)

# %%
from google.colab import files
files.download(submission_path)
